# %% [markdown]
# # Test Modeller for SPY Option Calls and Puts
#
# Using Word Vector

# %%
# Load in data
import pandas as pd

DATA_PATH='data/raw.csv'

data = pd.read_csv(DATA_PATH)
data = data.dropna()
data
# Out:
#                    date                                               text  \
# 2   2024/05/22 12:06:00  Q29zbWV0aWMgUHJvY2VkdXJlcw0KDQpQdWJsaXNoZWQgTW...
# 3   2024/05/21 14:42:00  QWxsIFRoaW5ncyBTdW1tZXINCg0KUHVibGlzaGVkIE1heS...
# 4   2024/05/20 13:02:00  R3JhZHVhdGlvbiDwn46TDQoNClB1Ymxpc2hlZCBNYXkgMj...
# 5   2024/05/17 14:26:00  VHJlbmRzIFRha2Vhd2F5cyB0aGlzIFdlZWsNCg0KUHVibG...
# 6   2024/05/16 12:44:00  QmVhdXR5IFJlcG9ydDogQXByaWwgMjAyNA0KDQpQdWJsaX...
# 7   2024/05/15 13:28:00  V2VhbHRoIEdhcA0KDQpQdWJsaXNoZWQgTWF5IDE1LCAyMD...
# 8   2024/05/14 13:11:00  V05CQSBUaXAtT2ZmIPCfj4ANCg0KUHVibGlzaGVkIE1heS...
# 9   2024/05/13 13:20:00  VmlueWwNCg0KUHVibGlzaGVkIE1heSAxMywgMjAyNA0KDQ...
# 10  2024/05/10 13:01:00  VHJlbmRzIFRha2Vhd2F5cyB0aGlzIFdlZWsNCg0KUHVibG...
# 11  2024/05/09 12:44:00  UmVkIEZsYWdzIPCfmqkNCg0KUHVibGlzaGVkIE1heSA5LC...
# 12  2024/05/08 15:26:00  TW90aGVyJ3MgRGF5IFNwZWNpYWwNCg0KUHVibGlzaGVkIE...
# 13  2024/05/07 14:14:00  QnJlYWt1cHMgYW5kIFJlbGF0aW9uc2hpcCBTdGFuZGFyZH...
# 14  2024/05/06 12:57:00  SUNZTUk6IEFwcmlsDQoNClB1Ymxpc2hlZCBNYXkgNiwgMj...
# 15  2024/05/03 13:00:00  VHJlbmRzIFRha2Vhd2F5cyB0aGlzIFdlZWsNCg0KUHVibG...
# 16  2024/05/02 12:50:00  Q2FtcHVzIFByb3Rlc3RzDQoNClB1Ymxpc2hlZCBNYXkgMi...
# 17  2024/05/01 13:00:00  SG9ub3JpbmcgQXNpYW4gYW5kIFBhc2lmaWthIEFuY2VzdH...
# 18  2024/04/30 12:23:00  U3VtbWVyIFRyYXZlbA0KDQpQdWJsaXNoZWQgQXByaWwgMz...
# 19  2024/04/29 12:53:00  UHV6emxlcyAmIEdhbWVzDQoNClB1Ymxpc2hlZCBBcHJpbC...
# 20  2024/04/26 12:39:00  Q29sbGVnZSBBZG1pc3Npb25zIGFuZCBEZWNpc2lvbnMNCg...
# 21  2024/04/25 13:15:00  TkZMIERyYWZ0IPCfj4gNCg0KUHVibGlzaGVkIEFwcmlsID...
# 22  2024/04/24 12:30:00  VFYgU3BlY2lhbA0KDQpQdWJsaXNoZWQgQXByaWwgMjQsID...
# 23  2024/04/23 12:51:00  R2FyZGVuaW5n8J+Mtw0KDQpQdWJsaXNoZWQgQXByaWwgMj...
# 24  2024/04/22 12:46:00  RWFydGggRGF5IFNwZWNpYWwNCg0KUHVibGlzaGVkIEFwcm...
# 25  2024/04/19 11:59:00  UHJvbQ0KDQoNClB1Ymxpc2hlZCBBcHJpbCAxOSwgMjAyNA...
# 49  2024/03/14 13:20:00  TmF0aW9uYWwgV29tZW4ncyBTb2NjZXIgTGVhZ3VlIOKavQ...
# 50  2024/03/13 13:23:00  UGVyc29uYWxpdHkgVGVzdHMNCg0KUHVibGlzaGVkIE1hcm...
# 51  2024/03/12 13:02:00  UmFtYWRhbiBNdWJhcmFrDQoNClB1Ymxpc2hlZCBNYXJjaC...
# 52  2024/03/08 12:07:00  SW50ZXJuYXRpb25hbCBXb21lbidzIERheQ0KDQpQdWJsaX...
# 53  2024/03/06 12:50:00  U3ByaW5nIEJyZWFrDQoNClB1Ymxpc2hlZCBNYXJjaCA2LC...
# 54  2024/03/05 12:50:00  SUNZTUk6IEZlYnJ1YXJ5DQoNClB1Ymxpc2hlZCBNYXJjaC...
# 55  2024/03/04 12:21:00  U3VwZXIgVHVlc2RheQ0KDQpQdWJsaXNoZWQgTWFyY2ggNC...
# 56  2024/03/01 13:05:00  TWFraW5nIEZyaWVuZHMg4oCiIExvbmVsaW5lc3MNCg0KUH...
# 57  2024/02/29 13:19:00  RGVtZW50aWENCg0KUHVibGlzaGVkIEZlYnJ1YXJ5IDI5LC...
# 58  2024/02/28 13:03:00  SVZGICYgUmVwcm9kdWN0aXZlIEhlYWx0aA0KDQpQdWJsaX...
# 59  2024/02/27 12:38:00  TWljaGlnYW4gUHJpbWFyeSBlbGVjdGlvbnMNCg0KUHVibG...
# 60  2024/02/26 14:30:00  Qm9va3MgYW5kIFJlYWRpbmcgU3BlY2lhbA0KDQpQdWJsaX...
#
#     one_day_call  one_day_put  two_day_call  two_day_put
# 2           2.20        -6.14         -0.59        -3.98
# 3           1.40        -2.38          3.08        -5.26
# 4           0.35        -2.09          0.21        -3.57
# 5           3.78         1.78          3.82         1.38
# 6          -1.01        -3.21          0.95        -1.05
# 7           2.73        -0.25          0.73        -1.47
# 8           9.36         4.46         10.80         7.82
# 9           3.13        -0.14          9.38         4.48
# 10          2.14        -0.79          3.30         0.03
# 11          3.54         0.49          3.57         0.64
# 12          2.91        -0.59          5.34         2.29
# 13          0.92        -1.68          3.39        -0.11
# 14          3.89         1.77          3.06         0.46
# 15          5.90         2.59          7.86         5.74
# 16         10.21         6.22         14.27        10.96
# 17          5.47        -0.87         12.13         8.14
# 18          1.42        -6.90         -0.88        -7.22
# 19         -0.38        -7.96         -1.75       -10.07
# 20          1.53        -1.97          0.34        -7.24
# 21          8.26         4.08          9.13         5.63
# 22          0.18        -6.60          5.79         1.61
# 23          1.90        -2.34         -1.20        -7.98
# 24          8.32         1.76          9.60         5.36
# 25          4.79        -2.16          8.50         1.94
# 26         -0.29        -6.89          1.63        -5.32
# 27          2.81        -2.76         -0.86        -7.46
# 28          1.37        -5.73         -0.72        -6.29
# 29          1.54        -2.75          1.26        -5.84
# 30          3.50        -8.22         -5.30        -9.59
# 31          0.52        -6.22          0.00       -11.72
# 32          6.64        -0.76          2.98        -3.76
# 33         -1.07        -5.14          2.25        -5.15
# 34          0.90        -5.50         -3.69        -7.76
# 35         -1.42        -7.85         -1.11        -7.51
# 36          3.24        -7.87         -0.19        -6.62
# 37          3.39         0.11          6.31        -4.80
# 38         -2.78        -5.28         -0.81        -4.09
# 39          1.08        -2.33         -4.32        -6.82
# 40          4.41         2.58          4.18         0.77
# 41          2.03        -1.69          3.43         1.60
# 42          1.09        -2.09          2.72        -1.00
# 43         -0.49        -1.83          0.14        -3.04
# 44         -1.15        -2.79         -2.81        -4.15
# 45          8.58         6.38          7.08         5.44
# 46          6.08         0.54          9.57         7.37
# 47          2.49        -2.39          7.11         1.57
# 48          6.35         3.31          6.87         1.99
# 49          0.13        -3.45          3.91         0.87
# 50          1.72        -3.59         -3.71        -7.29
# 51          4.83         2.03          4.67        -0.64
# 52         -1.14        -4.52          4.36        -2.16
# 53          5.87        -0.21          8.20         1.11
# 54          5.59         1.94          9.41         3.33
# 55         -0.61        -6.49          0.67        -2.98
# 56          3.94         1.74          0.53        -5.35
# 57          5.62         0.89          6.53         4.33
# 58          3.97        -0.42          7.52         2.79
# 59          1.51        -0.39          4.39         0.00
# 60         -0.13        -2.54         -0.43        -2.33

# %%
import numpy as np
# Create a new column that contains the combined values from the last 4 columns
DATA_LABEL = 'multi_target_label'
data[DATA_LABEL] = data.iloc[:, -4:].apply(lambda row: np.array(row), axis=1)
data
# Out:
#                    date                                               text  \
# 2   2024/05/22 12:06:00  Q29zbWV0aWMgUHJvY2VkdXJlcw0KDQpQdWJsaXNoZWQgTW...
# 3   2024/05/21 14:42:00  QWxsIFRoaW5ncyBTdW1tZXINCg0KUHVibGlzaGVkIE1heS...
# 4   2024/05/20 13:02:00  R3JhZHVhdGlvbiDwn46TDQoNClB1Ymxpc2hlZCBNYXkgMj...
# 5   2024/05/17 14:26:00  VHJlbmRzIFRha2Vhd2F5cyB0aGlzIFdlZWsNCg0KUHVibG...
# 6   2024/05/16 12:44:00  QmVhdXR5IFJlcG9ydDogQXByaWwgMjAyNA0KDQpQdWJsaX...
# 7   2024/05/15 13:28:00  V2VhbHRoIEdhcA0KDQpQdWJsaXNoZWQgTWF5IDE1LCAyMD...
# 8   2024/05/14 13:11:00  V05CQSBUaXAtT2ZmIPCfj4ANCg0KUHVibGlzaGVkIE1heS...
# 9   2024/05/13 13:20:00  VmlueWwNCg0KUHVibGlzaGVkIE1heSAxMywgMjAyNA0KDQ...
# 10  2024/05/10 13:01:00  VHJlbmRzIFRha2Vhd2F5cyB0aGlzIFdlZWsNCg0KUHVibG...
# 11  2024/05/09 12:44:00  UmVkIEZsYWdzIPCfmqkNCg0KUHVibGlzaGVkIE1heSA5LC...
# 12  2024/05/08 15:26:00  TW90aGVyJ3MgRGF5IFNwZWNpYWwNCg0KUHVibGlzaGVkIE...
# 13  2024/05/07 14:14:00  QnJlYWt1cHMgYW5kIFJlbGF0aW9uc2hpcCBTdGFuZGFyZH...
# 14  2024/05/06 12:57:00  SUNZTUk6IEFwcmlsDQoNClB1Ymxpc2hlZCBNYXkgNiwgMj...
# 15  2024/05/03 13:00:00  VHJlbmRzIFRha2Vhd2F5cyB0aGlzIFdlZWsNCg0KUHVibG...
# 16  2024/05/02 12:50:00  Q2FtcHVzIFByb3Rlc3RzDQoNClB1Ymxpc2hlZCBNYXkgMi...
# 17  2024/05/01 13:00:00  SG9ub3JpbmcgQXNpYW4gYW5kIFBhc2lmaWthIEFuY2VzdH...
# 15          5.90         2.59          7.86         5.74
# 16         10.21         6.22         14.27        10.96
# 17          5.47        -0.87         12.13         8.14
# 18          1.42        -6.90         -0.88        -7.22
# 19         -0.38        -7.96         -1.75       -10.07
# 20          1.53        -1.97          0.34        -7.24
# 21          8.26         4.08          9.13         5.63
# 22          0.18        -6.60          5.79         1.61
# 23          1.90        -2.34         -1.20        -7.98
# 24          8.32         1.76          9.60         5.36
# 25          4.79        -2.16          8.50         1.94
# 26         -0.29        -6.89          1.63        -5.32
# 27          2.81        -2.76         -0.86        -7.46
# 28          1.37        -5.73         -0.72        -6.29
# 29          1.54        -2.75          1.26        -5.84
# 30          3.50        -8.22         -5.30        -9.59
# 31          0.52        -6.22          0.00       -11.72
# 32          6.64        -0.76          2.98        -3.76
# 33         -1.07        -5.14          2.25        -5.15
# 34          0.90        -5.50         -3.69        -7.76
# 35         -1.42        -7.85         -1.11        -7.51
# 36          3.24        -7.87         -0.19        -6.62
# 37          3.39         0.11          6.31        -4.80
# 38         -2.78        -5.28         -0.81        -4.09
# 39          1.08        -2.33         -4.32        -6.82
# 40          4.41         2.58          4.18         0.77
# 41          2.03        -1.69          3.43         1.60
# 42          1.09        -2.09          2.72        -1.00
# 43         -0.49        -1.83          0.14        -3.04
# 44         -1.15        -2.79         -2.81        -4.15
# 45          8.58         6.38          7.08         5.44
# 46          6.08         0.54          9.57         7.37
# 47          2.49        -2.39          7.11         1.57
# 48          6.35         3.31          6.87         1.99
# 49          0.13        -3.45          3.91         0.87
# 50          1.72        -3.59         -3.71        -7.29
# 51          4.83         2.03          4.67        -0.64
# 52         -1.14        -4.52          4.36        -2.16
# 53          5.87        -0.21          8.20         1.11
# 54          5.59         1.94          9.41         3.33
# 55         -0.61        -6.49          0.67        -2.98
# 56          3.94         1.74          0.53        -5.35
# 57          5.62         0.89          6.53         4.33
# 58          3.97        -0.42          7.52         2.79
# 59          1.51        -0.39          4.39         0.00
# 60         -0.13        -2.54         -0.43        -2.33
#
#                multi_target_label
# 2      [2.2, -6.14, -0.59, -3.98]
# 3       [1.4, -2.38, 3.08, -5.26]
# 4      [0.35, -2.09, 0.21, -3.57]
# 5        [3.78, 1.78, 3.82, 1.38]
# 6     [-1.01, -3.21, 0.95, -1.05]
# 7      [2.73, -0.25, 0.73, -1.47]
# 8        [9.36, 4.46, 10.8, 7.82]
# 9       [3.13, -0.14, 9.38, 4.48]
# 10       [2.14, -0.79, 3.3, 0.03]
# 11       [3.54, 0.49, 3.57, 0.64]
# 12      [2.91, -0.59, 5.34, 2.29]
# 13     [0.92, -1.68, 3.39, -0.11]
# 14       [3.89, 1.77, 3.06, 0.46]
# 15        [5.9, 2.59, 7.86, 5.74]
# 16    [10.21, 6.22, 14.27, 10.96]
# 17     [5.47, -0.87, 12.13, 8.14]
# 18     [1.42, -6.9, -0.88, -7.22]
# 19  [-0.38, -7.96, -1.75, -10.07]
# 20     [1.53, -1.97, 0.34, -7.24]
# 21       [8.26, 4.08, 9.13, 5.63]
# 22       [0.18, -6.6, 5.79, 1.61]
# 23      [1.9, -2.34, -1.2, -7.98]
# 24        [8.32, 1.76, 9.6, 5.36]
# 25       [4.79, -2.16, 8.5, 1.94]
# 26    [-0.29, -6.89, 1.63, -5.32]
# 27    [2.81, -2.76, -0.86, -7.46]
# 28    [1.37, -5.73, -0.72, -6.29]
# 29     [1.54, -2.75, 1.26, -5.84]
# 30      [3.5, -8.22, -5.3, -9.59]
# 31     [0.52, -6.22, 0.0, -11.72]
# 32     [6.64, -0.76, 2.98, -3.76]
# 33    [-1.07, -5.14, 2.25, -5.15]
# 34      [0.9, -5.5, -3.69, -7.76]
# 35   [-1.42, -7.85, -1.11, -7.51]
# 36    [3.24, -7.87, -0.19, -6.62]
# 37       [3.39, 0.11, 6.31, -4.8]
# 38   [-2.78, -5.28, -0.81, -4.09]
# 39    [1.08, -2.33, -4.32, -6.82]
# 40       [4.41, 2.58, 4.18, 0.77]
# 41       [2.03, -1.69, 3.43, 1.6]
# 42      [1.09, -2.09, 2.72, -1.0]
# 43    [-0.49, -1.83, 0.14, -3.04]
# 44   [-1.15, -2.79, -2.81, -4.15]
# 45       [8.58, 6.38, 7.08, 5.44]
# 46       [6.08, 0.54, 9.57, 7.37]
# 47      [2.49, -2.39, 7.11, 1.57]
# 48       [6.35, 3.31, 6.87, 1.99]
# 49      [0.13, -3.45, 3.91, 0.87]
# 50    [1.72, -3.59, -3.71, -7.29]
# 51      [4.83, 2.03, 4.67, -0.64]
# 52    [-1.14, -4.52, 4.36, -2.16]
# 53       [5.87, -0.21, 8.2, 1.11]
# 54       [5.59, 1.94, 9.41, 3.33]
# 55    [-0.61, -6.49, 0.67, -2.98]
# 56      [3.94, 1.74, 0.53, -5.35]
# 57       [5.62, 0.89, 6.53, 4.33]
# 58      [3.97, -0.42, 7.52, 2.79]
# 59       [1.51, -0.39, 4.39, 0.0]
# 60   [-0.13, -2.54, -0.43, -2.33]

# %%
import base64
import dateutil.parser

BASE64_COLUMN_NAME='text'
TEXT_COLUMN_NAME='text'
data[TEXT_COLUMN_NAME] = data[BASE64_COLUMN_NAME].apply(lambda x: base64.b64decode(x).decode())
data
# Out:
#                    date                                               text  \
# 2   2024/05/22 12:06:00  Cosmetic Procedures\r\n\r\nPublished May 22, 2...
# 3   2024/05/21 14:42:00  All Things Summer\r\n\r\nPublished May 21, 202...
# 4   2024/05/20 13:02:00  Graduation 🎓\r\n\r\nPublished May 20, 2024\r\n...
# 5   2024/05/17 14:26:00  Trends Takeaways this Week\r\n\r\nPublished Ma...
# 6   2024/05/16 12:44:00  Beauty Report: April 2024\r\n\r\nPublished May...
# 7   2024/05/15 13:28:00  Wealth Gap\r\n\r\nPublished May 15, 2024\r\n\r...
# 8   2024/05/14 13:11:00  WNBA Tip-Off 🏀\r\n\r\nPublished May 14, 2024\r...
# 9   2024/05/13 13:20:00  Vinyl\r\n\r\nPublished May 13, 2024\r\n\r\n\r\...
# 10  2024/05/10 13:01:00  Trends Takeaways this Week\r\n\r\nPublished Ma...
#
# 46  2024/03/19 13:06:00  💍Marriage and Divorce Trends💔\r\n\r\nPublished...
# 47  2024/03/18 12:57:00  March Madness 🏀\r\n\r\nPublished March 18, 202...
# 48  2024/03/15 12:33:00  Super Commuting\r\n\r\nPublished March 15, 202...
# 49  2024/03/14 13:20:00  National Women's Soccer League ⚽\r\n\r\nPublis...
# 50  2024/03/13 13:23:00  Personality Tests\r\n\r\nPublished March 13, 2...
# 51  2024/03/12 13:02:00  Ramadan Mubarak\r\n\r\nPublished March 12, 202...
# 52  2024/03/08 12:07:00  International Women's Day\r\n\r\nPublished Mar...
# 53  2024/03/06 12:50:00  Spring Break\r\n\r\nPublished March 6, 2024\r\...
# 54  2024/03/05 12:50:00  ICYMI: February\r\n\r\nPublished March 5, 2024...
# 55  2024/03/04 12:21:00  Super Tuesday\r\n\r\nPublished March 4, 2024\r...
# 56  2024/03/01 13:05:00  Making Friends • Loneliness\r\n\r\nPublished M...
# 57  2024/02/29 13:19:00  Dementia\r\n\r\nPublished February 29, 2024\r\...
# 58  2024/02/28 13:03:00  IVF & Reproductive Health\r\n\r\nPublished Feb...
# 59  2024/02/27 12:38:00  Michigan Primary elections\r\n\r\nPublished Fe...
# 60  2024/02/26 14:30:00  Books and Reading Special\r\n\r\nPublished Feb...
#
#     one_day_call  one_day_put  two_day_call  two_day_put  \
# 2           2.20        -6.14         -0.59        -3.98
# 3           1.40        -2.38          3.08        -5.26
# 4           0.35        -2.09          0.21        -3.57
# 5           3.78         1.78          3.82         1.38
# 6          -1.01        -3.21          0.95        -1.05
# 7           2.73        -0.25          0.73        -1.47
# 8           9.36         4.46         10.80         7.82
# 9           3.13        -0.14          9.38         4.48
# 10          2.14        -0.79          3.30         0.03
# 11          3.54         0.49          3.57         0.64
# 12          2.91        -0.59          5.34         2.29
# 13          0.92        -1.68          3.39        -0.11
# 14          3.89         1.77          3.06         0.46
# 15          5.90         2.59          7.86         5.74
# 16         10.21         6.22         14.27        10.96
# 17          5.47        -0.87         12.13         8.14
# 18          1.42        -6.90         -0.88        -7.22
# 19         -0.38        -7.96         -1.75       -10.07
# 20          1.53        -1.97          0.34        -7.24
# 21          8.26         4.08          9.13         5.63
# 22          0.18        -6.60          5.79         1.61
# 23          1.90        -2.34         -1.20        -7.98
# 24          8.32         1.76          9.60         5.36
# 25          4.79        -2.16          8.50         1.94
# 26         -0.29        -6.89          1.63        -5.32
# 27          2.81        -2.76         -0.86        -7.46
# 28          1.37        -5.73         -0.72        -6.29
# 29          1.54        -2.75          1.26        -5.84
# 30          3.50        -8.22         -5.30        -9.59
# 31          0.52        -6.22          0.00       -11.72
# 32          6.64        -0.76          2.98        -3.76
# 33         -1.07        -5.14          2.25        -5.15
# 34          0.90        -5.50         -3.69        -7.76
# 35         -1.42        -7.85         -1.11        -7.51
# 36          3.24        -7.87         -0.19        -6.62
# 37          3.39         0.11          6.31        -4.80
# 38         -2.78        -5.28         -0.81        -4.09
# 39          1.08        -2.33         -4.32        -6.82
# 40          4.41         2.58          4.18         0.77
# 41          2.03        -1.69          3.43         1.60
# 42          1.09        -2.09          2.72        -1.00
# 43         -0.49        -1.83          0.14        -3.04
# 44         -1.15        -2.79         -2.81        -4.15
# 45          8.58         6.38          7.08         5.44
# 46          6.08         0.54          9.57         7.37
# 47          2.49        -2.39          7.11         1.57
# 48          6.35         3.31          6.87         1.99
# 49          0.13        -3.45          3.91         0.87
# 50          1.72        -3.59         -3.71        -7.29
# 51          4.83         2.03          4.67        -0.64
# 52         -1.14        -4.52          4.36        -2.16
# 53          5.87        -0.21          8.20         1.11
# 54          5.59         1.94          9.41         3.33
# 55         -0.61        -6.49          0.67        -2.98
# 56          3.94         1.74          0.53        -5.35
# 57          5.62         0.89          6.53         4.33
# 58          3.97        -0.42          7.52         2.79
# 59          1.51        -0.39          4.39         0.00
# 60         -0.13        -2.54         -0.43        -2.33
#
#                multi_target_label
# 2      [2.2, -6.14, -0.59, -3.98]
# 3       [1.4, -2.38, 3.08, -5.26]
# 4      [0.35, -2.09, 0.21, -3.57]
# 5        [3.78, 1.78, 3.82, 1.38]
# 6     [-1.01, -3.21, 0.95, -1.05]
# 7      [2.73, -0.25, 0.73, -1.47]
# 8        [9.36, 4.46, 10.8, 7.82]
# 9       [3.13, -0.14, 9.38, 4.48]
# 10       [2.14, -0.79, 3.3, 0.03]
# 11       [3.54, 0.49, 3.57, 0.64]
# 12      [2.91, -0.59, 5.34, 2.29]
# 13     [0.92, -1.68, 3.39, -0.11]
# 14       [3.89, 1.77, 3.06, 0.46]
# 15        [5.9, 2.59, 7.86, 5.74]
# 16    [10.21, 6.22, 14.27, 10.96]
# 17     [5.47, -0.87, 12.13, 8.14]
# 18     [1.42, -6.9, -0.88, -7.22]
# 19  [-0.38, -7.96, -1.75, -10.07]
# 20     [1.53, -1.97, 0.34, -7.24]
# 21       [8.26, 4.08, 9.13, 5.63]
# 22       [0.18, -6.6, 5.79, 1.61]
# 23      [1.9, -2.34, -1.2, -7.98]
# 24        [8.32, 1.76, 9.6, 5.36]
# 25       [4.79, -2.16, 8.5, 1.94]
# 26    [-0.29, -6.89, 1.63, -5.32]
# 27    [2.81, -2.76, -0.86, -7.46]
# 28    [1.37, -5.73, -0.72, -6.29]
# 29     [1.54, -2.75, 1.26, -5.84]
# 30      [3.5, -8.22, -5.3, -9.59]
# 31     [0.52, -6.22, 0.0, -11.72]
# 32     [6.64, -0.76, 2.98, -3.76]
# 33    [-1.07, -5.14, 2.25, -5.15]
# 34      [0.9, -5.5, -3.69, -7.76]
# 35   [-1.42, -7.85, -1.11, -7.51]
# 36    [3.24, -7.87, -0.19, -6.62]
# 37       [3.39, 0.11, 6.31, -4.8]
# 38   [-2.78, -5.28, -0.81, -4.09]
# 39    [1.08, -2.33, -4.32, -6.82]
# 40       [4.41, 2.58, 4.18, 0.77]
# 41       [2.03, -1.69, 3.43, 1.6]
# 42      [1.09, -2.09, 2.72, -1.0]
# 43    [-0.49, -1.83, 0.14, -3.04]
# 44   [-1.15, -2.79, -2.81, -4.15]
# 45       [8.58, 6.38, 7.08, 5.44]
# 46       [6.08, 0.54, 9.57, 7.37]
# 47      [2.49, -2.39, 7.11, 1.57]
# 48       [6.35, 3.31, 6.87, 1.99]
# 49      [0.13, -3.45, 3.91, 0.87]
# 50    [1.72, -3.59, -3.71, -7.29]
# 51      [4.83, 2.03, 4.67, -0.64]
# 52    [-1.14, -4.52, 4.36, -2.16]
# 53       [5.87, -0.21, 8.2, 1.11]
# 54       [5.59, 1.94, 9.41, 3.33]
# 55    [-0.61, -6.49, 0.67, -2.98]
# 56      [3.94, 1.74, 0.53, -5.35]
# 57       [5.62, 0.89, 6.53, 4.33]
# 58      [3.97, -0.42, 7.52, 2.79]
# 59       [1.51, -0.39, 4.39, 0.0]
# 60   [-0.13, -2.54, -0.43, -2.33]

# %%
TRAIN_TEST_RATIO = 0.2

def split_dataset(X, y, test_ratio):
    shuffled_indices = np.random.permutation(len(X))
    test_set_size = int(len(X) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return X.iloc[train_indices], y.iloc[train_indices].to_numpy(), X.iloc[test_indices], y.iloc[test_indices].to_numpy()

X_train, t_train, X_test, t_test = split_dataset(data, data[DATA_LABEL], TRAIN_TEST_RATIO)

print(f"X_train.shape:\t{X_train.shape}")
print(f"t_train.shape:\t{t_train.shape}")
print(f"X_test.shape:\t{X_test.shape}")
print(f"t_test.shape:\t{t_test.shape}")
# Out:
# X_train.shape:	(48, 7)
# t_train.shape:	(48,)
# X_test.shape:	(11, 7)
# t_test.shape:	(11,)

# %%
t_train.shape
t_train_reshaped = np.vstack(t_train)
t_train_reshaped.shape
# Out:
# (48, 4)

# %%
t_test_reshaped = np.vstack(t_test)
t_test_reshaped.shape
# Out:
# (11, 4)

# %% [markdown]
# Pipeline which creates word vectors, but alwos mixes in the day of the week as a feature.

# %%
from sklearn.pipeline import Pipeline, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputRegressor, RegressorChain
from sklearn.svm import LinearSVR, SVR

# Feature Extraction
text_preprocess = Pipeline([
    ('count', CountVectorizer()),
    ('transform', TfidfTransformer())
])

# Combine text feature extraction with day_of_week feature
ct = ColumnTransformer([
    ('text', text_preprocess, 'text'),
    ('dow', FunctionTransformer(lambda x: date_to_day_of_week(x)), ['date'])
])

def date_to_day_of_week(x):
  x['date'] = x['date'].apply(lambda row: dateutil.parser.parse(row).weekday())
  return x

# Add the final regressor to the pipeline
pipe = Pipeline([
    ('features', ct),
    ('reg', RegressorChain(base_estimator=SVR()))
])

#pipe.fit(X_train, t_train_reshaped)

# %% [markdown]
# Custom scorer for 2d label.

# %%
from sklearn.metrics import make_scorer

def mse(y_true, y_pred):
  diff = np.square(y_true - y_pred)
  return np.mean(diff, axis=0)

def mse_scorer(y_true, y_pred):
  diff = np.square(y_true - y_pred)
  return np.mean(diff)

score = make_scorer(mse_scorer, greater_is_better=False)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor

# Tested a couple of differant hyper-parameters in the end settled on these ones.
ANALYSERS = ['char_wb']
NGRAMS = [(1,14)]
#ESTIMATORS = [LinearSVR(dual='auto', C=1), SVR(C=1), SVR(C=10), SVR(C=100), SVR(C=1000)]
ESTIMATORS = [RandomForestRegressor()]

param_grid = [
    {
        "features__text__count__ngram_range": NGRAMS,
        "features__text__count__analyzer": ANALYSERS,
        "reg__base_estimator": ESTIMATORS
    }
]
grid = GridSearchCV(pipe, param_grid=param_grid, scoring=score)
grid.fit(X_train, t_train_reshaped)
grid.best_estimator_.get_params()
# Out:
# {'memory': None,
#  'steps': [('features',
#    ColumnTransformer(transformers=[('text',
#                                     Pipeline(steps=[('count',
#                                                      CountVectorizer(analyzer='char_wb',
#                                                                      ngram_range=(1,
#                                                                                   14))),
#                                                     ('transform',
#                                                      TfidfTransformer())]),
#                                     'text'),
#                                    ('dow',
#                                     FunctionTransformer(func=<function <lambda> at 0x177902de0>),
#                                     ['date'])])),
#   ('reg', RegressorChain(base_estimator=RandomForestRegressor()))],
#  'verbose': False,
#  'features': ColumnTransformer(transformers=[('text',
#                                   Pipeline(steps=[('count',
#                                                    CountVectorizer(analyzer='char_wb',
#                                                                    ngram_range=(1,
#                                                                                 14))),
#                                                   ('transform',
#                                                    TfidfTransformer())]),
#                                   'text'),
#                                  ('dow',
#                                   FunctionTransformer(func=<function <lambda> at 0x177902de0>),
#                                   ['date'])]),
#  'reg': RegressorChain(base_estimator=RandomForestRegressor()),
#  'features__force_int_remainder_cols': True,
#  'features__n_jobs': None,
#  'features__remainder': 'drop',
#  'features__sparse_threshold': 0.3,
#  'features__transformer_weights': None,
#  'features__transformers': [('text',
#    Pipeline(steps=[('count',
#                     CountVectorizer(analyzer='char_wb', ngram_range=(1, 14))),
#                    ('transform', TfidfTransformer())]),
#    'text'),
#   ('dow',
#    FunctionTransformer(func=<function <lambda> at 0x177902de0>),
#    ['date'])],
#  'features__verbose': False,
#  'features__verbose_feature_names_out': True,
#  'features__text': Pipeline(steps=[('count',
#                   CountVectorizer(analyzer='char_wb', ngram_range=(1, 14))),
#                  ('transform', TfidfTransformer())]),
#  'features__dow': FunctionTransformer(func=<function <lambda> at 0x177902de0>),
#  'features__text__memory': None,
#  'features__text__steps': [('count',
#    CountVectorizer(analyzer='char_wb', ngram_range=(1, 14))),
#   ('transform', TfidfTransformer())],
#  'features__text__verbose': False,
#  'features__text__count': CountVectorizer(analyzer='char_wb', ngram_range=(1, 14)),
#  'features__text__transform': TfidfTransformer(),
#  'features__text__count__analyzer': 'char_wb',
#  'features__text__count__binary': False,
#  'features__text__count__decode_error': 'strict',
#  'features__text__count__dtype': numpy.int64,
#  'features__text__count__encoding': 'utf-8',
#  'features__text__count__input': 'content',
#  'features__text__count__lowercase': True,
#  'features__text__count__max_df': 1.0,
#  'features__text__count__max_features': None,
#  'features__text__count__min_df': 1,
#  'features__text__count__ngram_range': (1, 14),
#  'features__text__count__preprocessor': None,
#  'features__text__count__stop_words': None,
#  'features__text__count__strip_accents': None,
#  'features__text__count__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'features__text__count__tokenizer': None,
#  'features__text__count__vocabulary': None,
#  'features__text__transform__norm': 'l2',
#  'features__text__transform__smooth_idf': True,
#  'features__text__transform__sublinear_tf': False,
#  'features__text__transform__use_idf': True,
#  'features__dow__accept_sparse': False,
#  'features__dow__check_inverse': True,
#  'features__dow__feature_names_out': None,
#  'features__dow__func': <function __main__.<lambda>(x)>,
#  'features__dow__inv_kw_args': None,
#  'features__dow__inverse_func': None,
#  'features__dow__kw_args': None,
#  'features__dow__validate': False,
#  'reg__base_estimator__bootstrap': True,
#  'reg__base_estimator__ccp_alpha': 0.0,
#  'reg__base_estimator__criterion': 'squared_error',
#  'reg__base_estimator__max_depth': None,
#  'reg__base_estimator__max_features': 1.0,
#  'reg__base_estimator__max_leaf_nodes': None,
#  'reg__base_estimator__max_samples': None,
#  'reg__base_estimator__min_impurity_decrease': 0.0,
#  'reg__base_estimator__min_samples_leaf': 1,
#  'reg__base_estimator__min_samples_split': 2,
#  'reg__base_estimator__min_weight_fraction_leaf': 0.0,
#  'reg__base_estimator__monotonic_cst': None,
#  'reg__base_estimator__n_estimators': 100,
#  'reg__base_estimator__n_jobs': None,
#  'reg__base_estimator__oob_score': False,
#  'reg__base_estimator__random_state': None,
#  'reg__base_estimator__verbose': 0,
#  'reg__base_estimator__warm_start': False,
#  'reg__base_estimator': RandomForestRegressor(),
#  'reg__cv': None,
#  'reg__order': None,
#  'reg__random_state': None,
#  'reg__verbose': False}

# %%
model = grid.best_estimator_

print(f"Test Mean Squared Error:\t{mse(t_test_reshaped, model.predict(X_test))}")
print(f"Test Score:\t{score(model, X_test, t_test_reshaped)}")
print(f"Train Mean Squared Error:\t{mse(t_train_reshaped, model.predict(X_train))}")
print(f"Train Score:\t{score(model, X_train, t_train_reshaped)}")
# Out:
# Test Mean Squared Error:	[ 9.87374184 23.17630249 24.04542853 53.40457929]
# Test Score:	-27.625013037272733
# Train Mean Squared Error:	[1.30014073 1.5185779  2.83303479 3.32364813]
# Train Score:	-2.2438503884895837

# %%
# Predict
filepath1 = "data/1d-may-24-outlook.txt"
filepath2 = "data/2d-may-23-outlook.txt" 

with open(filepath1, 'r') as file:
    predict_data1 = file.read()
with open(filepath2, 'r') as file:
    predict_data2 = file.read()
predict_data1 = base64.b64decode(predict_data1).decode()
predict_data1 = pd.DataFrame({'text': [predict_data1], 'date': ['May 24 2024']})

predict_data2 = base64.b64decode(predict_data2).decode()
predict_data2 = pd.DataFrame({'text': [predict_data2], 'date': ['May 23 2024']})

# %%
# Actual For May 24 T+1, T+2 predicted (high, low)
# (1.02999999999997, -2.37, TDD, TBD)
model.predict(predict_data1)
# Out:
# array([[3.61  , 0.8326, 4.3677, 1.2686]])

# %%
# Actual For May 23 T+1, T+2 predicted (high, low)
# (0.919999999999959, -2.46900000000005, 1.15999999999997, -2.24000000000001)
model.predict(predict_data2)
# Out:
# array([[ 2.3019, -3.2236,  1.9274, -5.2089]])
